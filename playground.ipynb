# %%
import json
import pandas as pd 
from pathlib import Path

# %%
f_wb_sch = '/Users/jacquelinewong/Documents/GitHub/YOLO/ref/workbook_schema.json'
f_sch_gis = '/Users/jacquelinewong/Documents/GitHub/YOLO/ref/schema_Group_income_statement.json'

with open(f_wb_sch, 'r') as f:
    sch_wb = json.load(f)

sch_wb.keys()
# Out:
# dict_keys(['workbook', 'total_sheets', 'processed_sheets', 'all_sheet_names', 'sheets'])

# %%
sch_wb['sheets'][2].keys()
# Out:
# dict_keys(['sheet_type', 'dimensions', 'merged_ranges', 'column_headers', 'data_start_row', 'sections', 'footnotes', 'sheet'])

# %%
for k, v in sch_wb['sheets'][2].items():
    print(k)
    print(v)
    print()
# Out:
# sheet_type
# semi_structured
#
# dimensions
# {'rows': 90, 'cols': 19}
#
# merged_ranges
# ['A90:I90', 'B5:F5', 'H5:I5', 'B53:F53', 'H53:I53', 'B65:F65', 'H65:I65']
#
# column_headers
# {'0': 'HSBC / HSBC Holdings plc consolidated income statement', '1': 'Quarter ended', '7': 'Year to date'}
#
# data_start_row
# 5
#
# sections
# [{'label': '', 'role': 'section_header', 'bold': False, 'indent': 0, 'outline_level': 0, 'children': [{'label': 'Reported ($m)', 'role': 'subtotal', 'bold': True, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 46022.0, 'col_2': 45930.0, 'col_3': 45838.0, 'col_4': 45747.0}}, {'label': 'Net interest income', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 9196.0, 'col_2': 8777.0, 'col_3': 8519.0, 'col_4': 8302.0}}, {'label': 'Net fee income', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 3194.0, 'col_2': 3506.0, 'col_3': 3319.0, 'col_4': 3324.0}}, {'label': 'Other operating income', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 3974.0, 'col_2': 5505.0, 'col_3': 4635.0, 'col_4': 6023.0}}, {'label': "Net operating income before change in expected credit losses and other credit impairment charges ('Revenue')", 'role': 'subtotal', 'bold': True, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 16364.0, 'col_2': 17788.0, 'col_3': 16473.0, 'col_4': 17649.0}}, {'label': "Change in expected credit losses and other credit impairment charges ('ECL')", 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': -901.0, 'col_2': -1008.0, 'col_3': -1065.0, 'col_4': -876.0}}, {'label': 'Total operating expenses', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': -9330.0, 'col_2': -10076.0, 'col_3': -8920.0, 'col_4': -8102.0}}, {'label': 'Share of profit in associates and joint ventures less impairment', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 669.0, 'col_2': 591.0, 'col_3': -162.0, 'col_4': 813.0}}, {'label': 'Profit/(loss) before tax', 'role': 'subtotal', 'bold': True, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 6802.0, 'col_2': 7295.0, 'col_3': 6326.0, 'col_4': 9484.0}}, {'label': 'Tax credit/(charge)', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': -1615.0, 'col_2': -1792.0, 'col_3': -1455.0, 'col_4': -1914.0}}, {'label': 'Profit/(loss) after tax', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 5187.0, 'col_2': 5503.0, 'col_3': 4871.0, 'col_4': 7570.0}}, {'label': 'Profit/(loss) attributable to:', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {}}, {'label': "- ordinary shareholders of the parent company ('PAOS')", 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 4719.0, 'col_2': 4873.0, 'col_3': 4578.0, 'col_4': 6932.0}}, {'label': '- other equity holders of the parent company', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 225.0, 'col_2': 411.0, 'col_3': 155.0, 'col_4': 392.0}}, {'label': '- non-controlling interests', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 243.0, 'col_2': 219.0, 'col_3': 138.0, 'col_4': 246.0}}, {'label': 'Impairment of goodwill and other intangible assets (net of tax)', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 80.0, 'col_2': 40.0, 'col_3': 24.0, 'col_4': 0.0}}, {'label': 'PAOS net of goodwill impairment', 'role': 'line_item', 'bold': False, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 4799.0, 'col_2': 4913.0, 'col_3': 4602.0, 'col_4': 6932.0}}]}, {'label': 'Constant currency  ($m)', 'role': 'section_header', 'bold': True, 'font_size': 9.0, 'indent': 0, 'outline_level': 0, 'children': [{'label': 'Revenue', 'role': 'subtotal', 'bold': True, 'indent': 0, 'outline_level': 0, 'sample_values': {'Quarter ended': 16364.0, 'col_2 ...
#
# footnotes
# ['1 We have revised the adjustments made to average tangible equity for the purposes of computing our return on average tangible equity (‘RoTE’) excluding notable items measure. Prior to this, we adjusted average tangible equity for the average impact of notable items whereas from 2025 we no longer make adjustments to average tangible equity. Comparatives have been re-presented on the revised basis.']
#
# sheet
# Group income statement

# %%
len(sch_wb['sheets'][2]['sections'])
# Out:
# 8

# %%
sch_wb['sheets'][2]['sections'][0].keys()
# Out:
# dict_keys(['label', 'role', 'bold', 'indent', 'outline_level', 'children'])

# %%
sch_wb['sheets'][2]['sections'][0]
# Out:
# {'label': '',
#  'role': 'section_header',
#  'bold': False,
#  'indent': 0,
#  'outline_level': 0,
#  'children': [{'label': 'Reported ($m)',
#    'role': 'subtotal',
#    'bold': True,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 46022.0,
#     'col_2': 45930.0,
#     'col_3': 45838.0,
#     'col_4': 45747.0}},
#   {'label': 'Net interest income',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 9196.0,
#     'col_2': 8777.0,
#     'col_3': 8519.0,
#     'col_4': 8302.0}},
#   {'label': 'Net fee income',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 3194.0,
#     'col_2': 3506.0,
#     'col_3': 3319.0,
#     'col_4': 3324.0}},
#   {'label': 'Other operating income',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 3974.0,
#     'col_2': 5505.0,
#     'col_3': 4635.0,
#     'col_4': 6023.0}},
#   {'label': "Net operating income before change in expected credit losses and other credit impairment charges ('Revenue')",
#    'role': 'subtotal',
#    'bold': True,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 16364.0,
#     'col_2': 17788.0,
#     'col_3': 16473.0,
#     'col_4': 17649.0}},
#   {'label': "Change in expected credit losses and other credit impairment charges ('ECL')",
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': -901.0,
#     'col_2': -1008.0,
#     'col_3': -1065.0,
#     'col_4': -876.0}},
#   {'label': 'Total operating expenses',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': -9330.0,
#     'col_2': -10076.0,
#     'col_3': -8920.0,
#     'col_4': -8102.0}},
#   {'label': 'Share of profit in associates and joint ventures less impairment',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 669.0,
#     'col_2': 591.0,
#     'col_3': -162.0,
#     'col_4': 813.0}},
#   {'label': 'Profit/(loss) before tax',
#    'role': 'subtotal',
#    'bold': True,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 6802.0,
#     'col_2': 7295.0,
#     'col_3': 6326.0,
#     'col_4': 9484.0}},
#   {'label': 'Tax credit/(charge)',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': -1615.0,
#     'col_2': -1792.0,
#     'col_3': -1455.0,
#     'col_4': -1914.0}},
#   {'label': 'Profit/(loss) after tax',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 5187.0,
#     'col_2': 5503.0,
#     'col_3': 4871.0,
#     'col_4': 7570.0}},
#   {'label': 'Profit/(loss) attributable to:',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {}},
#   {'label': "- ordinary shareholders of the parent company ('PAOS')",
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 4719.0,
#     'col_2': 4873.0,
#     'col_3': 4578.0,
#     'col_4': 6932.0}},
#   {'label': '- other equity holders of the parent company',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 225.0,
#     'col_2': 411.0,
#     'col_3': 155.0,
#     'col_4': 392.0}},
#   {'label': '- non-controlling interests',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 243.0,
#     'col_2': 219.0,
#     'col_3': 138.0,
#     'col_4': 246.0}},
#   {'label': 'Impairment of goodwill and other intangible assets (net of tax)',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 80.0,
#     'col_2': 40.0,
#     'col_3': 24.0,
#     'col_4': 0.0}},
#   {'label': 'PAOS net of goodwill impairment',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Quarter ended': 4799.0,
#     'col_2': 4913.0,
#     'col_3': 4602.0,
#     'col_4': 6932.0}}]}

# %%
f_cr = '/Users/jacquelinewong/Documents/GitHub/YOLO/test-generator.json'
with open(f_cr, 'r') as f:
    cr = json.load(f)

cr.keys()
# Out:
# dict_keys(['workbook', 'total_sheets', 'processed_sheets', 'all_sheet_names', 'sheets'])

# %%
cr['total_sheets']
# Out:
# 21

# %%
cr['all_sheet_names']
# Out:
# ['Cover - Notice',
#  'Cover - Index',
#  'Group income statement',
#  'Group balance sheet',
#  'Group MVOI',
#  'Group NIM',
#  'Hong Kong business',
#  'UK business',
#  'CIB business',
#  'IWPB business',
#  'Corporate Centre',
#  'HBUK',
#  'HCIB',
#  'HBAP (consol)',
#  'HBAP (HK)',
#  'HNAH',
#  'HBCA',
#  'Grupo Financiero (Mexico)',
#  'HBME',
#  'Other trading entities',
#  'Credit risk']

# %%
cr['sheets'][0].keys()
# Out:
# dict_keys(['sheet_type', 'dimensions', 'merged_ranges', 'column_headers', 'data_start_row', 'sections', 'footnotes', 'sheet'])

# %%
len(cr['sheets'][0]['sections'])
# Out:
# 7

# %%
cr['sheets'][0]['sections'][0]
# Out:
# {'label': '',
#  'role': 'section_header',
#  'bold': False,
#  'indent': 0,
#  'outline_level': 0,
#  'children': [{'label': 'Loans and advances to customers at amortised cost',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 893433.0,
#     'Stage 2 / $m': 80936.0,
#     'Stage 3 / $m': 24389.0,
#     'POCI2 / $m': 333.0}},
#   {'label': '– personal',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 446696.0,
#     'Stage 2 / $m': 23887.0,
#     'Stage 3 / $m': 3945.0,
#     'POCI2 / $m': 0.0}},
#   {'label': '– corporate and commercial',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 349763.0,
#     'Stage 2 / $m': 54636.0,
#     'Stage 3 / $m': 19966.0,
#     'POCI2 / $m': 140.0}},
#   {'label': '– non-bank financial institutions',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 96974.0,
#     'Stage 2 / $m': 2413.0,
#     'Stage 3 / $m': 478.0,
#     'POCI2 / $m': 193.0}},
#   {'label': 'Loans and advances to banks at amortised cost',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 108336.0,
#     'Stage 2 / $m': 132.0,
#     'Stage 3 / $m': 1.0,
#     'POCI2 / $m': 0.0}},
#   {'label': 'Other financial assets measured at amortised cost',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 888491.0,
#     'Stage 2 / $m': 1651.0,
#     'Stage 3 / $m': 184.0,
#     'POCI2 / $m': 0.0}},
#   {'label': 'Loans and other credit-related commitments',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 669648.0,
#     'Stage 2 / $m': 20488.0,
#     'Stage 3 / $m': 652.0,
#     'POCI2 / $m': 4.0}},
#   {'label': '– personal',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 270494.0,
#     'Stage 2 / $m': 1945.0,
#     'Stage 3 / $m': 92.0,
#     'POCI2 / $m': 0.0}},
#   {'label': '– corporate and commercial',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 255740.0,
#     'Stage 2 / $m': 14649.0,
#     'Stage 3 / $m': 560.0,
#     'POCI2 / $m': 4.0}},
#   {'label': '– financial',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 143414.0,
#     'Stage 2 / $m': 3894.0,
#     'Stage 3 / $m': 0.0,
#     'POCI2 / $m': 0.0}},
#   {'label': 'Financial guarantees',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 15913.0,
#     'Stage 2 / $m': 1371.0,
#     'Stage 3 / $m': 192.0,
#     'POCI2 / $m': 0.0}},
#   {'label': '– personal',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 1446.0,
#     'Stage 2 / $m': 0.0,
#     'Stage 3 / $m': 0.0,
#     'POCI2 / $m': 0.0}},
#   {'label': '– corporate and commercial',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 10071.0,
#     'Stage 2 / $m': 1287.0,
#     'Stage 3 / $m': 190.0,
#     'POCI2 / $m': 0.0}},
#   {'label': '– financial',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 4396.0,
#     'Stage 2 / $m': 84.0,
#     'Stage 3 / $m': 2.0,
#     'POCI2 / $m': 0.0}},
#   {'label': 'At 31 December 2025',
#    'role': 'subtotal',
#    'bold': True,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {'Gross carrying/nominal amount1 / Stage 1 / $m': 2575821.0,
#     'Stage 2 / $m': 104578.0,
#     'Stage 3 / $m': 25418.0,
#     'POCI2 / $m': 337.0}},
#   {'label': '1 Represents the maximum amount at risk should the contracts be fully drawn upon and clients default.',
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {}},
#   {'label': "2 Purchased or originated credit impaired ('POCI').",
#    'role': 'line_item',
#    'bold': False,
#    'indent': 0,
#    'outline_level': 0,
#    'sample_values': {}}]}

# %%
dir = Path('/Users/jacquelinewong/Documents/GitHub/YOLO/data/op_csv/credit_risk')
# List all CSV files in the directory
csv_files = list(dir.glob('*.csv'))
for f in csv_files:
    print(f.name)
# Out:
# corporate_and_commercial.csv
# by_legal_entity_2.csv
# total_wholesale_lending_for_loans_and_advances_to_banks_and_customers_by_stage_distribution.csv
# total_personal_lending_for_loans_and_advances_to_customers_by_stage_distribution.csv
# stage_2_days_past_due_analysis_at_31_december_2025.csv
# by_legal_entity.csv
# section_01.csv

# %%
df = pd.read_csv(dir / 'corporate_and_commercial.csv')
df
# Out:
#    excel_row       role  indent  outline_level  \
# 0        117  line_item       0              0
# 1        118  line_item       0              0
# 2        119  line_item       0              0
# 3        120  line_item       0              0
# 4        121  line_item       0              0
# 5        122  line_item       0              0
# 6        123  line_item       0              0
# 7        124  line_item       0              0
# 8        125   subtotal       0              0
#
#                                                label  \
# 0                                   HSBC UK Bank plc
# 1                                      HSBC Bank plc
# 2  The Hongkong and Shanghai Banking Corporation ...
# 3                      HSBC Bank Middle East Limited
# 4                   HSBC North America Holdings Inc.
# 5                Grupo Financiero HSBC, S.A. de C.V.
# 6                             Other trading entities
# 7  Holding companies, shared service centres and ...
# 8                                At 31 December 2025
#
#    Gross carrying/nominal amount1 / Stage 1 / $m  Stage 2 / $m  Stage 3 / $m  \
# 0                                          79595         10239          3352
# 1                                          54392          4542          1655
# 2                                         171287         33157         12654
# 3                                          14087          1140          1161
# 4                                          18266          3271           517
# 5                                           9174          2139           342
# 6                                           2962           148           285
# 7                                              0             0             0
# 8                                         349763         54636         19966
#
#    POCI2 / $m  Total / $m  Allowance for ECL / Stage 1 / $m  Stage 2 / $m__2  \
# 0           0       93186                              -170             -322
# 1          58       60647                               -57              -88
# 2          77      217175                              -140             -476
# 3           5       16393                               -18              -31
# 4           0       22054                               -36              -95
# 5           0       11655                               -46              -48
# 6           0        3395                               -11               -4
# 7           0           0                                 0                0
# 8         140      424505                              -478            -1064
#
#    Stage 3 / $m__2  POCI2 / $m__2  Total / $m__2  \
# 0             -681              0          -1173
# 1             -552            -29           -726
# 2            -3596            -41          -4253
# 3             -586             -5           -640
# 4             -145              0           -276
# 5             -169              0           -263
# 6             -180              0           -195
# 7                0              0              0
# 8            -5909            -75          -7526
#
#    ECL coverage % / Stage 1 / %  Stage 2 / %  Stage 3 / %  POCI2 / %  \
# 0                           NaN          NaN          NaN        NaN
# 1                           NaN          NaN          NaN        NaN
# 2                           NaN          NaN          NaN        NaN
# 3                           NaN          NaN          NaN        NaN
# 4                           NaN          NaN          NaN        NaN
# 5                           NaN          NaN          NaN        NaN
# 6                           NaN          NaN          NaN        NaN
# 7                           NaN          NaN          NaN        NaN
# 8                           NaN          NaN          NaN        NaN
#
#    Total / %
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN

# %%
# Out:
# PosixPath('/Users/jacquelinewong/Documents/GitHub/YOLO/data/op_csv/credit_risk/section_01.csv')
